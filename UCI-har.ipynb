# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
import os

# %%
# 재현성을 위한 시드 설정
np.random.seed(42)
tf.random.set_seed(42)

# %%
# UCI HAR Dataset 로드 함수
def load_uci_har_dataset(data_path='UCI HAR Dataset'):
    """UCI HAR Dataset 로드"""

    def load_X(file_path):
        with open(file_path, 'r') as f:
            data = [list(map(float, line.strip().split())) for line in f]
        return np.array(data)

    def load_y(file_path):
        with open(file_path, 'r') as f:
            data = [int(line.strip()) for line in f]
        return np.array(data) - 1  # 0-based indexing

    # Train data
    X_train = load_X(os.path.join(data_path, 'train', 'X_train.txt'))
    y_train = load_y(os.path.join(data_path, 'train', 'y_train.txt'))

    # Test data
    X_test = load_X(os.path.join(data_path, 'test', 'X_test.txt'))
    y_test = load_y(os.path.join(data_path, 'test', 'y_test.txt'))

    return X_train, y_train, X_test, y_test

# %%
# Squeeze-and-Excitation Block
class SEBlock(layers.Layer):
    def __init__(self, ratio=8, **kwargs):
        super(SEBlock, self).__init__(**kwargs)
        self.ratio = ratio

    def build(self, input_shape):
        channels = input_shape[-1]
        self.squeeze = layers.GlobalAveragePooling1D()
        self.excitation = keras.Sequential([
            layers.Dense(channels // self.ratio, activation='relu'),
            layers.Dense(channels, activation='sigmoid')
        ])
        super(SEBlock, self).build(input_shape)

    def call(self, inputs):
        se = self.squeeze(inputs)
        se = self.excitation(se)
        se = layers.Reshape((1, inputs.shape[-1]))(se)
        return layers.Multiply()([inputs, se])

    def get_config(self):
        config = super().get_config()
        config.update({'ratio': self.ratio})
        return config

# %%
# Attention Layer (Self-Attention)
class SelfAttention(layers.Layer):
    def __init__(self, units=128, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)
        self.units = units

    def build(self, input_shape):
        self.W1 = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='attention_W1'
        )
        self.W2 = self.add_weight(
            shape=(input_shape[-1], self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='attention_W2'
        )
        self.V = self.add_weight(
            shape=(self.units, 1),
            initializer='glorot_uniform',
            trainable=True,
            name='attention_V'
        )
        super(SelfAttention, self).build(input_shape)

    def call(self, x):
        # x shape: (batch, timesteps, features)
        score = tf.nn.tanh(tf.tensordot(x, self.W1, axes=1))
        attention_weights = tf.nn.softmax(tf.tensordot(score, self.V, axes=1), axis=1)
        context_vector = attention_weights * x
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %%
# Inception-style Multi-Scale Block
def inception_block(x, filters=32):
    """Inception-style parallel convolutions"""

    # 1x1 conv
    conv1 = layers.Conv1D(filters, 1, padding='same', activation='relu')(x)
    conv1 = layers.BatchNormalization()(conv1)

    # 1x1 -> 3x3 conv
    conv3 = layers.Conv1D(filters, 1, padding='same', activation='relu')(x)
    conv3 = layers.Conv1D(filters, 3, padding='same', activation='relu')(conv3)
    conv3 = layers.BatchNormalization()(conv3)

    # 1x1 -> 5x5 conv
    conv5 = layers.Conv1D(filters, 1, padding='same', activation='relu')(x)
    conv5 = layers.Conv1D(filters, 5, padding='same', activation='relu')(conv5)
    conv5 = layers.BatchNormalization()(conv5)

    # 3x3 MaxPool -> 1x1 conv
    pool = layers.MaxPooling1D(3, strides=1, padding='same')(x)
    pool_conv = layers.Conv1D(filters, 1, padding='same', activation='relu')(pool)
    pool_conv = layers.BatchNormalization()(pool_conv)

    # Concatenate all
    concat = layers.Concatenate()([conv1, conv3, conv5, pool_conv])

    return concat

# %%
# Enhanced Residual Block with SE
def enhanced_residual_block(x, filters=64, kernel_size=3):
    """Residual block with Squeeze-and-Excitation"""
    shortcut = x

    x = layers.Conv1D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Conv1D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    # SE Block
    x = SEBlock(ratio=8)(x)

    # Match dimensions
    if shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(filters, 1, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)

    return x

# %%
# 최적화된 메인 모델
def build_optimized_har_model(input_shape=(51, 11), num_classes=6):
    """
    최적화된 HAR 모델: Inception + SE-ResNet + BiLSTM + Multi-Head Attention
    목표: 96%+ 정확도
    """

    inputs = layers.Input(shape=input_shape)

    # Initial feature extraction with Inception
    x = inception_block(inputs, filters=24)  # 24*4 = 96 filters
    x = layers.Dropout(0.25)(x)

    # SE-ResNet blocks
    x = enhanced_residual_block(x, filters=64, kernel_size=3)
    x = layers.Dropout(0.25)(x)

    x = enhanced_residual_block(x, filters=96, kernel_size=3)
    x = layers.Dropout(0.25)(x)

    x = enhanced_residual_block(x, filters=128, kernel_size=3)
    x = layers.Dropout(0.3)(x)

    # Bidirectional LSTM layers
    x = layers.Bidirectional(
        layers.LSTM(96, return_sequences=True, dropout=0.3, recurrent_dropout=0.2)
    )(x)

    x = layers.Bidirectional(
        layers.LSTM(64, return_sequences=True, dropout=0.3, recurrent_dropout=0.2)
    )(x)

    # Self-Attention
    attention_output = SelfAttention(units=128)(x)

    # Global pooling (both average and max)
    avg_pool = layers.GlobalAveragePooling1D()(x)
    max_pool = layers.GlobalMaxPooling1D()(x)

    # Combine attention and pooling
    x = layers.Concatenate()([attention_output, avg_pool, max_pool])

    # Dense layers with strong regularization
    x = layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(5e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(5e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)

    # Output layer
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# Cosine Annealing with Warm Restarts
class CosineAnnealingScheduler(keras.callbacks.Callback):
    def __init__(self, T_0=10, T_mult=2, eta_max=0.001, eta_min=1e-6):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_0 = T_0
        self.T_mult = T_mult
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.T_cur = 0
        self.T_i = T_0

    def on_epoch_begin(self, epoch, logs=None):
        if self.T_cur == self.T_i:
            self.T_cur = 0
            self.T_i *= self.T_mult

        lr = self.eta_min + 0.5 * (self.eta_max - self.eta_min) * \
             (1 + np.cos(np.pi * self.T_cur / self.T_i))

        self.model.optimizer.learning_rate.assign(lr)
        self.T_cur += 1

        if epoch % 10 == 0:
            print(f"\nEpoch {epoch}: Learning rate = {lr:.6f}")

# %%
# 모델 학습 함수
def train_model(X_train, y_train, X_test, y_test):
    """모델 학습 및 평가"""

    print("데이터 전처리 중...")

    # Reshape: 561 features -> 51 timesteps × 11 features
    n_timesteps = 51
    n_features = 11

    X_train_reshaped = X_train[:, :n_timesteps*n_features].reshape(-1, n_timesteps, n_features)
    X_test_reshaped = X_test[:, :n_timesteps*n_features].reshape(-1, n_timesteps, n_features)

    # 정규화
    scaler = StandardScaler()
    X_train_reshaped = scaler.fit_transform(X_train_reshaped.reshape(-1, n_features)).reshape(-1, n_timesteps, n_features)
    X_test_reshaped = scaler.transform(X_test_reshaped.reshape(-1, n_features)).reshape(-1, n_timesteps, n_features)

    # One-hot encoding
    y_train_cat = keras.utils.to_categorical(y_train, num_classes=6)
    y_test_cat = keras.utils.to_categorical(y_test, num_classes=6)

    # Class weights (클래스 불균형 대응)
    from sklearn.utils.class_weight import compute_class_weight
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weight_dict = dict(enumerate(class_weights))

    print(f"Train shape: {X_train_reshaped.shape}")
    print(f"Test shape: {X_test_reshaped.shape}")
    print(f"Class weights: {class_weight_dict}")

    # 모델 구축
    print("\n모델 구축 중...")
    model = build_optimized_har_model(input_shape=(n_timesteps, n_features), num_classes=6)

    # 모델 요약
    model.summary()

    # 파라미터 수 확인
    total_params = model.count_params()
    print(f"\n총 파라미터 수: {total_params:,} (제한: 1,000,000)")

    if total_params > 1000000:
        print("⚠️ 경고: 파라미터 수가 100만을 초과했습니다!")

    # Optimizer
    optimizer = keras.optimizers.AdamW(
        learning_rate=0.001,
        weight_decay=1e-4
    )

    # Compile with label smoothing
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    # Callbacks
    cosine_scheduler = CosineAnnealingScheduler(
        T_0=10,
        T_mult=2,
        eta_max=0.001,
        eta_min=1e-6
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=10,
        min_lr=1e-7,
        verbose=1
    )

    early_stop = EarlyStopping(
        monitor='val_accuracy',
        patience=30,
        restore_best_weights=True,
        verbose=1
    )

    checkpoint = ModelCheckpoint(
        'best_har_model_optimized.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )

    # 학습
    print("\n모델 학습 시작...")
    history = model.fit(
        X_train_reshaped, y_train_cat,
        batch_size=128,
        epochs=200,
        validation_data=(X_test_reshaped, y_test_cat),
        class_weight=class_weight_dict,
        callbacks=[cosine_scheduler, reduce_lr, early_stop, checkpoint],
        verbose=1
    )

    # 최종 평가
    print("\n최종 평가:")
    test_loss, test_accuracy = model.evaluate(X_test_reshaped, y_test_cat, verbose=0)
    print(f"Test Accuracy: {test_accuracy*100:.2f}%")
    print(f"Test Loss: {test_loss:.4f}")

    # 클래스별 성능 분석
    y_pred = model.predict(X_test_reshaped)
    y_pred_classes = np.argmax(y_pred, axis=1)

    from sklearn.metrics import classification_report, confusion_matrix

    print("\n=== Classification Report ===")
    class_names = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS',
                   'SITTING', 'STANDING', 'LAYING']
    print(classification_report(y_test, y_pred_classes, target_names=class_names))

    print("\n=== Confusion Matrix ===")
    cm = confusion_matrix(y_test, y_pred_classes)
    print(cm)

    # 클래스별 정확도
    print("\n=== 클래스별 정확도 ===")
    for i, name in enumerate(class_names):
        class_acc = cm[i, i] / cm[i, :].sum() * 100
        print(f"{name}: {class_acc:.2f}%")

    return model, history

# %%
# 메인 실행
if __name__ == "__main__":
    # 데이터 로드
    print("UCI HAR Dataset 로드 중...")
    data_path = '/content/drive/MyDrive/Colab Notebooks/AI-study/data/UCI HAR Dataset'
    X_train, y_train, X_test, y_test = load_uci_har_dataset(data_path)

    print(f"원본 데이터 크기:")
    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")

    # 모델 학습
    model, history = train_model(X_train, y_train, X_test, y_test)

    print("\n학습 완료! 최고 모델이 'best_har_model_optimized.keras'로 저장되었습니다.")
# Out:
# UCI HAR Dataset 로드 중...
# 원본 데이터 크기:
# X_train: (7352, 561), y_train: (7352,)
# X_test: (2947, 561), y_test: (2947,)
# 데이터 전처리 중...
# Train shape: (7352, 51, 11)
# Test shape: (2947, 51, 11)
# Class weights: {0: np.float64(0.9994562262098967), 1: np.float64(1.1419695557626592), 2: np.float64(1.2427315753887762), 3: np.float64(0.9528252980819077), 4: np.float64(0.8918000970402717), 5: np.float64(0.8708836768538261)}
#
# 모델 구축 중...
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 51, 11)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_35 (Conv1D)  │ (None, 51, 24)    │        288 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_37 (Conv1D)  │ (None, 51, 24)    │        288 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_4     │ (None, 51, 11)    │          0 │ input_layer_7[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_34 (Conv1D)  │ (None, 51, 24)    │        288 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_36 (Conv1D)  │ (None, 51, 24)    │      1,752 │ conv1d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_38 (Conv1D)  │ (None, 51, 24)    │      2,904 │ conv1d_37[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_39 (Conv1D)  │ (None, 51, 24)    │        288 │ max_pooling1d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 24)    │         96 │ conv1d_34[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 24)    │         96 │ conv1d_36[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 24)    │         96 │ conv1d_38[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 24)    │         96 │ conv1d_39[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 51, 96)    │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 51, 96)    │          0 │ concatenate_4[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_40 (Conv1D)  │ (None, 51, 64)    │     18,496 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 64)    │        256 │ conv1d_40[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 51, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 51, 64)    │          0 │ activation_12[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_41 (Conv1D)  │ (None, 51, 64)    │     12,352 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 64)    │        256 │ conv1d_41[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_42 (Conv1D)  │ (None, 51, 64)    │      6,208 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block_4          │ (None, 51, 64)    │      1,096 │ batch_normalizat… │
# │ (SEBlock)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 64)    │        256 │ conv1d_42[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 51, 64)    │          0 │ se_block_4[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 51, 64)    │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 51, 64)    │          0 │ activation_13[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_43 (Conv1D)  │ (None, 51, 96)    │     18,528 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 96)    │        384 │ conv1d_43[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 51, 96)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 51, 96)    │          0 │ activation_14[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_44 (Conv1D)  │ (None, 51, 96)    │     27,744 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 96)    │        384 │ conv1d_44[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_45 (Conv1D)  │ (None, 51, 96)    │      6,240 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block_5          │ (None, 51, 96)    │      2,412 │ batch_normalizat… │
# │ (SEBlock)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 96)    │        384 │ conv1d_45[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 51, 96)    │          0 │ se_block_5[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 51, 96)    │          0 │ add_7[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 51, 96)    │          0 │ activation_15[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_46 (Conv1D)  │ (None, 51, 128)   │     36,992 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 128)   │        512 │ conv1d_46[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 51, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 51, 128)   │          0 │ activation_16[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_47 (Conv1D)  │ (None, 51, 128)   │     49,280 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 128)   │        512 │ conv1d_47[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_48 (Conv1D)  │ (None, 51, 128)   │     12,416 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block_6          │ (None, 51, 128)   │      4,240 │ batch_normalizat… │
# │ (SEBlock)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 51, 128)   │        512 │ conv1d_48[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 51, 128)   │          0 │ se_block_6[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 51, 128)   │          0 │ add_8[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 51, 128)   │          0 │ activation_17[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 51, 192)   │    172,800 │ dropout_24[0][0]  │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_4     │ (None, 51, 128)   │    131,584 │ bidirectional_3[… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention_1    │ (None, 128)       │     32,896 │ bidirectional_4[… │
# │ (SelfAttention)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ bidirectional_4[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ bidirectional_4[… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 384)       │          0 │ self_attention_1… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 256)       │     98,560 │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_20[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 128)       │     32,896 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_21[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 6)         │        774 │ dropout_26[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 676,698 (2.58 MB)
#  Trainable params: 674,010 (2.57 MB)
#  Non-trainable params: 2,688 (10.50 KB)
# 총 파라미터 수: 676,698 (제한: 1,000,000)
#
# 모델 학습 시작...
#
# Epoch 0: Learning rate = 0.001000
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/base_optimizer.py:855: UserWarning: Gradients do not exist for variables ['self_attention_1/attention_W2'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2514 - loss: 2.5073
# Epoch 1: val_accuracy improved from -inf to 0.26977, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 104s 1s/step - accuracy: 0.2524 - loss: 2.5020 - val_accuracy: 0.2698 - val_loss: 1.7514 - learning_rate: 0.0010
# Epoch 2/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4233 - loss: 1.7445
# Epoch 2: val_accuracy improved from 0.26977 to 0.49610, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4245 - loss: 1.7421 - val_accuracy: 0.4961 - val_loss: 1.3784 - learning_rate: 9.7555e-04
# Epoch 3/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6255 - loss: 1.3677
# Epoch 3: val_accuracy did not improve from 0.49610
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.6260 - loss: 1.3667 - val_accuracy: 0.4248 - val_loss: 1.6382 - learning_rate: 9.0460e-04
# Epoch 4/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7181 - loss: 1.1745
# Epoch 4: val_accuracy did not improve from 0.49610
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7183 - loss: 1.1740 - val_accuracy: 0.4686 - val_loss: 1.9231 - learning_rate: 7.9410e-04
# Epoch 5/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7682 - loss: 1.0697
# Epoch 5: val_accuracy did not improve from 0.49610
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.7683 - loss: 1.0695 - val_accuracy: 0.4466 - val_loss: 2.1875 - learning_rate: 6.5485e-04
# Epoch 6/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7887 - loss: 1.0116
# Epoch 6: val_accuracy did not improve from 0.49610
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7887 - loss: 1.0115 - val_accuracy: 0.4401 - val_loss: 2.4334 - learning_rate: 5.0050e-04
# Epoch 7/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8067 - loss: 0.9839
# Epoch 7: val_accuracy did not improve from 0.49610
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.8068 - loss: 0.9839 - val_accuracy: 0.4710 - val_loss: 2.3863 - learning_rate: 3.4615e-04
# Epoch 8/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8313 - loss: 0.9611
# Epoch 8: val_accuracy did not improve from 0.49610
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.8315 - loss: 0.9609 - val_accuracy: 0.4628 - val_loss: 2.3840 - learning_rate: 2.0690e-04
# Epoch 9/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8443 - loss: 0.9467
# Epoch 9: val_accuracy improved from 0.49610 to 0.49746, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8444 - loss: 0.9467 - val_accuracy: 0.4975 - val_loss: 2.1000 - learning_rate: 9.6396e-05
# Epoch 10/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8396 - loss: 0.9479
# Epoch 10: val_accuracy improved from 0.49746 to 0.51069, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.8397 - loss: 0.9478 - val_accuracy: 0.5107 - val_loss: 2.0582 - learning_rate: 2.5447e-05
#
# Epoch 10: Learning rate = 0.001000
# Epoch 11/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8437 - loss: 0.9441
# Epoch 11: val_accuracy improved from 0.51069 to 0.60706, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8439 - loss: 0.9437 - val_accuracy: 0.6071 - val_loss: 1.7305 - learning_rate: 0.0010
# Epoch 12/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8771 - loss: 0.8889
# Epoch 12: val_accuracy did not improve from 0.60706
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8772 - loss: 0.8887 - val_accuracy: 0.5972 - val_loss: 1.8065 - learning_rate: 9.9385e-04
# Epoch 13/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8887 - loss: 0.8561
# Epoch 13: val_accuracy improved from 0.60706 to 0.66780, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8889 - loss: 0.8557 - val_accuracy: 0.6678 - val_loss: 1.4369 - learning_rate: 9.7555e-04
# Epoch 14/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9129 - loss: 0.8027
# Epoch 14: val_accuracy did not improve from 0.66780
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9130 - loss: 0.8025 - val_accuracy: 0.5504 - val_loss: 1.9081 - learning_rate: 9.4556e-04
# Epoch 15/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9170 - loss: 0.7829
# Epoch 15: val_accuracy improved from 0.66780 to 0.74958, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9171 - loss: 0.7827 - val_accuracy: 0.7496 - val_loss: 1.1414 - learning_rate: 9.0460e-04
# Epoch 16/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9355 - loss: 0.7479
# Epoch 16: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9356 - loss: 0.7479 - val_accuracy: 0.7139 - val_loss: 1.2664 - learning_rate: 8.5370e-04
# Epoch 17/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9406 - loss: 0.7303
# Epoch 17: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9406 - loss: 0.7303 - val_accuracy: 0.7241 - val_loss: 1.2235 - learning_rate: 7.9410e-04
# Epoch 18/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9422 - loss: 0.7149
# Epoch 18: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9422 - loss: 0.7148 - val_accuracy: 0.6607 - val_loss: 1.4527 - learning_rate: 7.2727e-04
# Epoch 19/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9522 - loss: 0.6901
# Epoch 19: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9521 - loss: 0.6902 - val_accuracy: 0.6233 - val_loss: 1.5950 - learning_rate: 6.5485e-04
# Epoch 20/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9487 - loss: 0.6870
# Epoch 20: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9487 - loss: 0.6869 - val_accuracy: 0.6532 - val_loss: 1.5012 - learning_rate: 5.7864e-04
#
# Epoch 20: Learning rate = 0.000501
# Epoch 21/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9550 - loss: 0.6750
# Epoch 21: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9551 - loss: 0.6749 - val_accuracy: 0.6437 - val_loss: 1.5280 - learning_rate: 5.0050e-04
# Epoch 22/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9544 - loss: 0.6653
# Epoch 22: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9545 - loss: 0.6653 - val_accuracy: 0.7238 - val_loss: 1.2223 - learning_rate: 4.2236e-04
# Epoch 23/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9651 - loss: 0.6487
# Epoch 23: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9652 - loss: 0.6486 - val_accuracy: 0.6644 - val_loss: 1.4555 - learning_rate: 3.4615e-04
# Epoch 24/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9655 - loss: 0.6478
# Epoch 24: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9655 - loss: 0.6477 - val_accuracy: 0.7380 - val_loss: 1.1717 - learning_rate: 2.7373e-04
# Epoch 25/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9618 - loss: 0.6440
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010345063492422923.
#
# Epoch 25: val_accuracy did not improve from 0.74958
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9618 - loss: 0.6440 - val_accuracy: 0.7384 - val_loss: 1.2039 - learning_rate: 2.0690e-04
# Epoch 26/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9643 - loss: 0.6396
# Epoch 26: val_accuracy improved from 0.74958 to 0.76654, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9643 - loss: 0.6395 - val_accuracy: 0.7665 - val_loss: 1.1228 - learning_rate: 1.4730e-04
# Epoch 27/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9624 - loss: 0.6419
# Epoch 27: val_accuracy did not improve from 0.76654
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9624 - loss: 0.6418 - val_accuracy: 0.7323 - val_loss: 1.2129 - learning_rate: 9.6396e-05
# Epoch 28/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9682 - loss: 0.6273
# Epoch 28: val_accuracy did not improve from 0.76654
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9683 - loss: 0.6272 - val_accuracy: 0.7296 - val_loss: 1.2359 - learning_rate: 5.5442e-05
# Epoch 29/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9695 - loss: 0.6254
# Epoch 29: val_accuracy did not improve from 0.76654
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9695 - loss: 0.6253 - val_accuracy: 0.7194 - val_loss: 1.2769 - learning_rate: 2.5447e-05
# Epoch 30/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9704 - loss: 0.6271
# Epoch 30: val_accuracy did not improve from 0.76654
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9704 - loss: 0.6271 - val_accuracy: 0.7279 - val_loss: 1.2448 - learning_rate: 7.1497e-06
#
# Epoch 30: Learning rate = 0.001000
# Epoch 31/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9647 - loss: 0.6314
# Epoch 31: val_accuracy improved from 0.76654 to 0.85918, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9647 - loss: 0.6315 - val_accuracy: 0.8592 - val_loss: 0.8517 - learning_rate: 0.0010
# Epoch 32/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9612 - loss: 0.6302
# Epoch 32: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9612 - loss: 0.6302 - val_accuracy: 0.7438 - val_loss: 1.1506 - learning_rate: 9.9846e-04
# Epoch 33/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9620 - loss: 0.6148
# Epoch 33: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9621 - loss: 0.6147 - val_accuracy: 0.7075 - val_loss: 1.3335 - learning_rate: 9.9385e-04
# Epoch 34/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9681 - loss: 0.6060
# Epoch 34: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9681 - loss: 0.6059 - val_accuracy: 0.8039 - val_loss: 0.9928 - learning_rate: 9.8620e-04
# Epoch 35/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9666 - loss: 0.5991
# Epoch 35: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9666 - loss: 0.5990 - val_accuracy: 0.7950 - val_loss: 1.0404 - learning_rate: 9.7555e-04
# Epoch 36/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9665 - loss: 0.5854
# Epoch 36: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9666 - loss: 0.5853 - val_accuracy: 0.7801 - val_loss: 1.0345 - learning_rate: 9.6198e-04
# Epoch 37/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9688 - loss: 0.5794
# Epoch 37: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9688 - loss: 0.5794 - val_accuracy: 0.8069 - val_loss: 0.9938 - learning_rate: 9.4556e-04
# Epoch 38/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9673 - loss: 0.5740
# Epoch 38: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9674 - loss: 0.5738 - val_accuracy: 0.7611 - val_loss: 1.1044 - learning_rate: 9.2639e-04
# Epoch 39/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9747 - loss: 0.5601
# Epoch 39: val_accuracy did not improve from 0.85918
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9747 - loss: 0.5600 - val_accuracy: 0.7927 - val_loss: 0.9933 - learning_rate: 9.0460e-04
# Epoch 40/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9709 - loss: 0.5533
# Epoch 40: val_accuracy improved from 0.85918 to 0.89311, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9710 - loss: 0.5532 - val_accuracy: 0.8931 - val_loss: 0.7509 - learning_rate: 8.8032e-04
#
# Epoch 40: Learning rate = 0.000854
# Epoch 41/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9751 - loss: 0.5447
# Epoch 41: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9751 - loss: 0.5446 - val_accuracy: 0.8483 - val_loss: 0.8360 - learning_rate: 8.5370e-04
# Epoch 42/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9723 - loss: 0.5430
# Epoch 42: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9723 - loss: 0.5429 - val_accuracy: 0.8890 - val_loss: 0.7303 - learning_rate: 8.2490e-04
# Epoch 43/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9783 - loss: 0.5303
# Epoch 43: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9783 - loss: 0.5303 - val_accuracy: 0.8415 - val_loss: 0.8688 - learning_rate: 7.9410e-04
# Epoch 44/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9818 - loss: 0.5210
# Epoch 44: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9818 - loss: 0.5210 - val_accuracy: 0.7431 - val_loss: 1.1696 - learning_rate: 7.6149e-04
# Epoch 45/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9789 - loss: 0.5212
# Epoch 45: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9789 - loss: 0.5211 - val_accuracy: 0.8463 - val_loss: 0.8479 - learning_rate: 7.2727e-04
# Epoch 46/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9802 - loss: 0.5174
# Epoch 46: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9802 - loss: 0.5175 - val_accuracy: 0.7618 - val_loss: 1.1562 - learning_rate: 6.9165e-04
# Epoch 47/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9808 - loss: 0.5134
# Epoch 47: val_accuracy did not improve from 0.89311
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9808 - loss: 0.5134 - val_accuracy: 0.7950 - val_loss: 1.0390 - learning_rate: 6.5485e-04
# Epoch 48/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9813 - loss: 0.5088
# Epoch 48: val_accuracy improved from 0.89311 to 0.89583, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9813 - loss: 0.5088 - val_accuracy: 0.8958 - val_loss: 0.7048 - learning_rate: 6.1711e-04
# Epoch 49/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9839 - loss: 0.5035
# Epoch 49: val_accuracy did not improve from 0.89583
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9839 - loss: 0.5034 - val_accuracy: 0.8500 - val_loss: 0.8381 - learning_rate: 5.7864e-04
# Epoch 50/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9829 - loss: 0.5040
# Epoch 50: val_accuracy did not improve from 0.89583
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9829 - loss: 0.5039 - val_accuracy: 0.8554 - val_loss: 0.8132 - learning_rate: 5.3969e-04
#
# Epoch 50: Learning rate = 0.000501
# Epoch 51/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9832 - loss: 0.4986
# Epoch 51: val_accuracy did not improve from 0.89583
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9832 - loss: 0.4986 - val_accuracy: 0.7974 - val_loss: 0.9814 - learning_rate: 5.0050e-04
# Epoch 52/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9862 - loss: 0.4966
# Epoch 52: val_accuracy did not improve from 0.89583
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9862 - loss: 0.4966 - val_accuracy: 0.8775 - val_loss: 0.7456 - learning_rate: 4.6131e-04
# Epoch 53/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9805 - loss: 0.5013
# Epoch 53: val_accuracy did not improve from 0.89583
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9805 - loss: 0.5013 - val_accuracy: 0.8347 - val_loss: 0.8701 - learning_rate: 4.2236e-04
# Epoch 54/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.4882
# Epoch 54: val_accuracy improved from 0.89583 to 0.91449, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9886 - loss: 0.4882 - val_accuracy: 0.9145 - val_loss: 0.6528 - learning_rate: 3.8389e-04
# Epoch 55/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9872 - loss: 0.4890
# Epoch 55: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9873 - loss: 0.4890 - val_accuracy: 0.8561 - val_loss: 0.8110 - learning_rate: 3.4615e-04
# Epoch 56/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9880 - loss: 0.4866
# Epoch 56: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9880 - loss: 0.4865 - val_accuracy: 0.8273 - val_loss: 0.8916 - learning_rate: 3.0935e-04
# Epoch 57/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9839 - loss: 0.4914
# Epoch 57: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9839 - loss: 0.4913 - val_accuracy: 0.8388 - val_loss: 0.8664 - learning_rate: 2.7373e-04
# Epoch 58/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9878 - loss: 0.4818
# Epoch 58: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9878 - loss: 0.4818 - val_accuracy: 0.8453 - val_loss: 0.8621 - learning_rate: 2.3951e-04
# Epoch 59/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9853 - loss: 0.4887
# Epoch 59: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9854 - loss: 0.4886 - val_accuracy: 0.8347 - val_loss: 0.8731 - learning_rate: 2.0690e-04
# Epoch 60/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9883 - loss: 0.4824
# Epoch 60: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9884 - loss: 0.4823 - val_accuracy: 0.8612 - val_loss: 0.7957 - learning_rate: 1.7610e-04
#
# Epoch 60: Learning rate = 0.000147
# Epoch 61/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9870 - loss: 0.4838
# Epoch 61: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9870 - loss: 0.4837 - val_accuracy: 0.8500 - val_loss: 0.8395 - learning_rate: 1.4730e-04
# Epoch 62/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9897 - loss: 0.4772
# Epoch 62: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9897 - loss: 0.4772 - val_accuracy: 0.8113 - val_loss: 0.9656 - learning_rate: 1.2068e-04
# Epoch 63/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9895 - loss: 0.4768
# Epoch 63: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9895 - loss: 0.4768 - val_accuracy: 0.8347 - val_loss: 0.8865 - learning_rate: 9.6396e-05
# Epoch 64/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9889 - loss: 0.4767
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.730311800609343e-05.
#
# Epoch 64: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9889 - loss: 0.4766 - val_accuracy: 0.8334 - val_loss: 0.8937 - learning_rate: 7.4606e-05
# Epoch 65/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9889 - loss: 0.4765
# Epoch 65: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9890 - loss: 0.4764 - val_accuracy: 0.8388 - val_loss: 0.8776 - learning_rate: 5.5442e-05
# Epoch 66/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.4764
# Epoch 66: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9893 - loss: 0.4764 - val_accuracy: 0.8412 - val_loss: 0.8723 - learning_rate: 3.9022e-05
# Epoch 67/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9879 - loss: 0.4771
# Epoch 67: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9879 - loss: 0.4771 - val_accuracy: 0.8419 - val_loss: 0.8758 - learning_rate: 2.5447e-05
# Epoch 68/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.4731
# Epoch 68: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9915 - loss: 0.4731 - val_accuracy: 0.8476 - val_loss: 0.8624 - learning_rate: 1.4801e-05
# Epoch 69/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.4724
# Epoch 69: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9923 - loss: 0.4724 - val_accuracy: 0.8480 - val_loss: 0.8568 - learning_rate: 7.1497e-06
# Epoch 70/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.4706
# Epoch 70: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9923 - loss: 0.4705 - val_accuracy: 0.8480 - val_loss: 0.8550 - learning_rate: 2.5398e-06
#
# Epoch 70: Learning rate = 0.001000
# Epoch 71/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9836 - loss: 0.4899
# Epoch 71: val_accuracy did not improve from 0.91449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9836 - loss: 0.4899 - val_accuracy: 0.8707 - val_loss: 0.7877 - learning_rate: 0.0010
# Epoch 72/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9762 - loss: 0.5024
# Epoch 72: val_accuracy improved from 0.91449 to 0.92229, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9762 - loss: 0.5024 - val_accuracy: 0.9223 - val_loss: 0.6459 - learning_rate: 9.9961e-04
# Epoch 73/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9802 - loss: 0.4948
# Epoch 73: val_accuracy did not improve from 0.92229
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9802 - loss: 0.4947 - val_accuracy: 0.8297 - val_loss: 0.9059 - learning_rate: 9.9846e-04
# Epoch 74/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9819 - loss: 0.4967
# Epoch 74: val_accuracy did not improve from 0.92229
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9819 - loss: 0.4967 - val_accuracy: 0.8473 - val_loss: 0.8944 - learning_rate: 9.9654e-04
# Epoch 75/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9803 - loss: 0.4914
# Epoch 75: val_accuracy did not improve from 0.92229
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9804 - loss: 0.4913 - val_accuracy: 0.9189 - val_loss: 0.6551 - learning_rate: 9.9385e-04
# Epoch 76/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9813 - loss: 0.4909
# Epoch 76: val_accuracy did not improve from 0.92229
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9812 - loss: 0.4910 - val_accuracy: 0.8948 - val_loss: 0.7154 - learning_rate: 9.9040e-04
# Epoch 77/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9789 - loss: 0.4977
# Epoch 77: val_accuracy improved from 0.92229 to 0.94197, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9790 - loss: 0.4977 - val_accuracy: 0.9420 - val_loss: 0.5861 - learning_rate: 9.8620e-04
# Epoch 78/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9773 - loss: 0.4987
# Epoch 78: val_accuracy improved from 0.94197 to 0.94435, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9773 - loss: 0.4985 - val_accuracy: 0.9444 - val_loss: 0.5770 - learning_rate: 9.8125e-04
# Epoch 79/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9875 - loss: 0.4753
# Epoch 79: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9875 - loss: 0.4753 - val_accuracy: 0.8351 - val_loss: 0.9014 - learning_rate: 9.7555e-04
# Epoch 80/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9845 - loss: 0.4809
# Epoch 80: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9845 - loss: 0.4808 - val_accuracy: 0.9440 - val_loss: 0.5755 - learning_rate: 9.6913e-04
#
# Epoch 80: Learning rate = 0.000962
# Epoch 81/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 0.4790
# Epoch 81: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9843 - loss: 0.4790 - val_accuracy: 0.8371 - val_loss: 0.8555 - learning_rate: 9.6198e-04
# Epoch 82/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9819 - loss: 0.4850
# Epoch 82: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9820 - loss: 0.4849 - val_accuracy: 0.8633 - val_loss: 0.8143 - learning_rate: 9.5412e-04
# Epoch 83/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9819 - loss: 0.4891
# Epoch 83: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9819 - loss: 0.4890 - val_accuracy: 0.8592 - val_loss: 0.8153 - learning_rate: 9.4556e-04
# Epoch 84/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9863 - loss: 0.4751
# Epoch 84: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9863 - loss: 0.4751 - val_accuracy: 0.9033 - val_loss: 0.6676 - learning_rate: 9.3631e-04
# Epoch 85/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 0.4791
# Epoch 85: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9842 - loss: 0.4792 - val_accuracy: 0.8124 - val_loss: 0.9552 - learning_rate: 9.2639e-04
# Epoch 86/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9850 - loss: 0.4747
# Epoch 86: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9850 - loss: 0.4747 - val_accuracy: 0.8483 - val_loss: 0.8532 - learning_rate: 9.1582e-04
# Epoch 87/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.4718
# Epoch 87: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9856 - loss: 0.4718 - val_accuracy: 0.8334 - val_loss: 0.8837 - learning_rate: 9.0460e-04
# Epoch 88/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.4692
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.00044638291001319885.
#
# Epoch 88: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9885 - loss: 0.4692 - val_accuracy: 0.8904 - val_loss: 0.7263 - learning_rate: 8.9277e-04
# Epoch 89/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9886 - loss: 0.4680
# Epoch 89: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9886 - loss: 0.4680 - val_accuracy: 0.9162 - val_loss: 0.6524 - learning_rate: 8.8032e-04
# Epoch 90/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9884 - loss: 0.4688
# Epoch 90: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9884 - loss: 0.4688 - val_accuracy: 0.9030 - val_loss: 0.6847 - learning_rate: 8.6729e-04
#
# Epoch 90: Learning rate = 0.000854
# Epoch 91/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9903 - loss: 0.4633
# Epoch 91: val_accuracy did not improve from 0.94435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9903 - loss: 0.4634 - val_accuracy: 0.9067 - val_loss: 0.6845 - learning_rate: 8.5370e-04
# Epoch 92/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.4666
# Epoch 92: val_accuracy improved from 0.94435 to 0.94910, saving model to best_har_model_optimized.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9888 - loss: 0.4665 - val_accuracy: 0.9491 - val_loss: 0.5550 - learning_rate: 8.3956e-04
# Epoch 93/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9879 - loss: 0.4671
# Epoch 93: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9879 - loss: 0.4671 - val_accuracy: 0.9406 - val_loss: 0.5777 - learning_rate: 8.2490e-04
# Epoch 94/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9892 - loss: 0.4673
# Epoch 94: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9892 - loss: 0.4672 - val_accuracy: 0.9372 - val_loss: 0.5726 - learning_rate: 8.0974e-04
# Epoch 95/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.4705
# Epoch 95: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9856 - loss: 0.4705 - val_accuracy: 0.9192 - val_loss: 0.6387 - learning_rate: 7.9410e-04
# Epoch 96/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.4647
# Epoch 96: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9886 - loss: 0.4647 - val_accuracy: 0.9026 - val_loss: 0.7031 - learning_rate: 7.7801e-04
# Epoch 97/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9888 - loss: 0.4664
# Epoch 97: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9888 - loss: 0.4664 - val_accuracy: 0.9162 - val_loss: 0.6402 - learning_rate: 7.6149e-04
# Epoch 98/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9897 - loss: 0.4600
# Epoch 98: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9898 - loss: 0.4600 - val_accuracy: 0.9325 - val_loss: 0.6022 - learning_rate: 7.4457e-04
# Epoch 99/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9890 - loss: 0.4660
# Epoch 99: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9890 - loss: 0.4660 - val_accuracy: 0.9321 - val_loss: 0.6180 - learning_rate: 7.2727e-04
# Epoch 100/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.4705
# Epoch 100: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9873 - loss: 0.4705 - val_accuracy: 0.8839 - val_loss: 0.7834 - learning_rate: 7.0962e-04
#
# Epoch 100: Learning rate = 0.000692
# Epoch 101/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9872 - loss: 0.4649
# Epoch 101: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9872 - loss: 0.4648 - val_accuracy: 0.8062 - val_loss: 0.9917 - learning_rate: 6.9165e-04
# Epoch 102/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9879 - loss: 0.4688
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.0003366927267052233.
#
# Epoch 102: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9880 - loss: 0.4687 - val_accuracy: 0.8331 - val_loss: 0.9179 - learning_rate: 6.7339e-04
# Epoch 103/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9932 - loss: 0.4544
# Epoch 103: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9932 - loss: 0.4544 - val_accuracy: 0.8476 - val_loss: 0.8621 - learning_rate: 6.5485e-04
# Epoch 104/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.4587
# Epoch 104: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9913 - loss: 0.4587 - val_accuracy: 0.8775 - val_loss: 0.7580 - learning_rate: 6.3608e-04
# Epoch 105/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.4576
# Epoch 105: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9911 - loss: 0.4576 - val_accuracy: 0.9389 - val_loss: 0.5857 - learning_rate: 6.1711e-04
# Epoch 106/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.4560
# Epoch 106: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9927 - loss: 0.4559 - val_accuracy: 0.8999 - val_loss: 0.6794 - learning_rate: 5.9795e-04
# Epoch 107/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9944 - loss: 0.4514
# Epoch 107: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9944 - loss: 0.4514 - val_accuracy: 0.8717 - val_loss: 0.7912 - learning_rate: 5.7864e-04
# Epoch 108/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.4583
# Epoch 108: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9920 - loss: 0.4583 - val_accuracy: 0.8700 - val_loss: 0.7976 - learning_rate: 5.5921e-04
# Epoch 109/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.4543
# Epoch 109: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9927 - loss: 0.4543 - val_accuracy: 0.9379 - val_loss: 0.5911 - learning_rate: 5.3969e-04
# Epoch 110/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.4574
# Epoch 110: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9921 - loss: 0.4574 - val_accuracy: 0.9410 - val_loss: 0.5767 - learning_rate: 5.2011e-04
#
# Epoch 110: Learning rate = 0.000501
# Epoch 111/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.4578
# Epoch 111: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9906 - loss: 0.4577 - val_accuracy: 0.8880 - val_loss: 0.7469 - learning_rate: 5.0050e-04
# Epoch 112/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9928 - loss: 0.4539
# Epoch 112: ReduceLROnPlateau reducing learning rate to 0.00024044486053753644.
#
# Epoch 112: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9928 - loss: 0.4538 - val_accuracy: 0.9247 - val_loss: 0.6351 - learning_rate: 4.8089e-04
# Epoch 113/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.4517
# Epoch 113: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9945 - loss: 0.4517 - val_accuracy: 0.9260 - val_loss: 0.6289 - learning_rate: 4.6131e-04
# Epoch 114/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9942 - loss: 0.4517
# Epoch 114: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9942 - loss: 0.4516 - val_accuracy: 0.9091 - val_loss: 0.6816 - learning_rate: 4.4179e-04
# Epoch 115/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.4521
# Epoch 115: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9933 - loss: 0.4521 - val_accuracy: 0.9308 - val_loss: 0.6183 - learning_rate: 4.2236e-04
# Epoch 116/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 0.4518
# Epoch 116: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9939 - loss: 0.4518 - val_accuracy: 0.9274 - val_loss: 0.6150 - learning_rate: 4.0305e-04
# Epoch 117/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.4536
# Epoch 117: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9933 - loss: 0.4536 - val_accuracy: 0.9206 - val_loss: 0.6361 - learning_rate: 3.8389e-04
# Epoch 118/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.4500
# Epoch 118: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9945 - loss: 0.4500 - val_accuracy: 0.8877 - val_loss: 0.7469 - learning_rate: 3.6492e-04
# Epoch 119/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.4504
# Epoch 119: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9934 - loss: 0.4504 - val_accuracy: 0.8680 - val_loss: 0.8314 - learning_rate: 3.4615e-04
# Epoch 120/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.4526
# Epoch 120: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9923 - loss: 0.4526 - val_accuracy: 0.8799 - val_loss: 0.7782 - learning_rate: 3.2761e-04
#
# Epoch 120: Learning rate = 0.000309
# Epoch 121/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9941 - loss: 0.4511
# Epoch 121: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9941 - loss: 0.4510 - val_accuracy: 0.8999 - val_loss: 0.7079 - learning_rate: 3.0935e-04
# Epoch 122/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9948 - loss: 0.4490
# Epoch 122: ReduceLROnPlateau reducing learning rate to 0.00014568972983397543.
#
# Epoch 122: val_accuracy did not improve from 0.94910
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9948 - loss: 0.4490 - val_accuracy: 0.9209 - val_loss: 0.6416 - learning_rate: 2.9138e-04
# Epoch 122: early stopping
# Restoring model weights from the end of the best epoch: 92.
#
# 최종 평가:
# Test Accuracy: 94.91%
# Test Loss: 0.5550
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step
#
# === Classification Report ===
#                     precision    recall  f1-score   support
#
#            WALKING       0.91      0.99      0.95       496
#   WALKING_UPSTAIRS       0.97      0.90      0.94       471
# WALKING_DOWNSTAIRS       0.97      0.95      0.96       420
#            SITTING       0.94      0.91      0.93       491
#           STANDING       0.92      0.94      0.93       532
#             LAYING       0.99      0.99      0.99       537
#
#           accuracy                           0.95      2947
#          macro avg       0.95      0.95      0.95      2947
#       weighted avg       0.95      0.95      0.95      2947
#
#
# === Confusion Matrix ===
# [[493   0   3   0   0   0]
#  [ 34 426  11   0   0   0]
#  [ 10  12 398   0   0   0]
#  [  0   0   0 448  39   4]
#  [  2   0   0  28 502   0]
#  [  0   0   0   0   7 530]]
#
# === 클래스별 정확도 ===
# WALKING: 99.40%
# WALKING_UPSTAIRS: 90.45%
# WALKING_DOWNSTAIRS: 94.76%
# SITTING: 91.24%
# STANDING: 94.36%
# LAYING: 98.70%
#
# 학습 완료! 최고 모델이 'best_har_model_optimized.keras'로 저장되었습니다.
